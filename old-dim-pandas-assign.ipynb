# %% [markdown]
# # Instructions
#
# For the second part of the assignment today, we're going to get a little bit of practice with `Pandas`. We'll ask that you do a couple of different things using the new tools that we learned about (methods for combining data sets, `pd.cut`, and `pivot tables`).

# %% [markdown]
# # Assignment Questions
#
# We'll be working with the `wine` datasets that are located in the `data` folder in this day's directory.
#
# 1) Read the `winequality-red.csv` data into a `DataFrame`, and the `winequality-white.csv` into another `DataFrame`.
#
# 2) Double check that you've read them in right by using some of the attributes and methods available on `DataFrames` for getting a general sense of your data (**Hint**: See `day10-intro_pandas`, `week5` if you need a refresher on these).
#
# 3) I've decided that this month I want to stay away from wines with relatively high alcohol content. To do that, I'm going to avoid any wines that have a greater alcohol content than the mean alcohol content, and you're going to help me do this. To achieve this, let's do the following:
#
#   * Find the mean alcohol content, separately, for reds and whites.
#   * Create a `Series` that holds whether each row in each `DataFrame` (the reds, and whites) has a higher alcohol content than the mean.
#   * Merge this `Series` onto the `DataFrame`. I can imagine doing this with either a `.join()` or using `pd.concat()`. For practice, do it with both. Note: merges with `Series` work the same way that they work with `DataFrames`.
#   * Return back to me all those rows that will help me stay away from those wines with a higher alcohol content.
#
#
# 4) Let's say that I want to get started on cutting back next month. This time, though, I want to focus on staying away from those wines with a high acidity. Specifically, I want to stay away from those wines that are in the highest bin of fixed acidity (highest bin out of 5). You're now going to help me do this. To achieve this, let's do the following:
#
#  * Separate the rows in each `DataFrame` into 5 equal width bins based off their fixed acidity.
#  * Merge the resulting `Series` holding these 5 bins onto the original `DataFrame`. I can imagine also doing this with either `.join()` or using `pd.concat()`. Try doing it with both for practice.
#  * Return back to me all those rows that are **not in ** the top bin in terms of fixed acidity.
#
# 5) Let's say that I now want to know how much my decision to avoid those wines with higher `alcohol` content is going to limit the `quality` of wines that I can drink. To figure this out, I want to know a couple of things:
#
#  * The average `alcohol` content for those reds above the mean `alcohol` level, by quality.
#  * The average `alcohol` content for those whites above the mean `alcohol` level, by quality.
#
#  Use a `pivot table` to solve this.
#
# 6) Now, do the same for my decision to avoid wines with a high acidity next month:
#
#  * Find the average `alcohol` content for reds, by `quality` and `fixed acidity` quintile.
#  * Find the average `alcohol` content for whites, by `quality` and `fixed acidity` quintile.
#
#   Use a `pivot table` to solve this.

# %%
import numpy as np
import pandas as pd

white = pd.read_csv('Numpy_pandas/data/winequality-white.csv', delimiter =';')
red = pd.read_csv('Numpy_pandas/data/winequality-red.csv', delimiter =';')
red_alc_mean = red['alcohol'].mean()
white_alc_mean = white['alcohol'].mean()

deviation_red = red['alcohol'] - red_alc_mean
#deviation_red.columns = ['deviation']
deviation_white = white['alcohol'] - white_alc_mean

#red2 = red.join(deviation_red)
#white2 = white.join(deviation_white)
red2 = pd.concat([deviation_red, red], axis=1)
white2 = pd.concat([deviation_white, white], axis=1)
test = red2[red2.iloc[:,0] > 0]      # returns all rows where the 1. col above 0

# 4
fixed_acidity_bins = np.arange(4, 17, 2.4)
fixed_acidity_series1 = pd.cut(red['fixed acidity'], bins=fixed_acidity_bins, labels=fixed_acidity_bins[:-1]) 
fixed_acidity_series1.name = 'fa_bin'
red_acidity = pd.concat([red, fixed_acidity_series1], axis=1)
red_acidity2 = red_acidity[red_acidity.iloc[:,-1].astype(float) < 13]
red_acidity2.sort_values('fa_bin')

fixed_acidity_bins2 = np.arange(white['fixed acidity'].min(),white['fixed acidity'].max(),(white['fixed acidity'].max()-white['fixed acidity'].min())/6)
fixed_acidity_series2 = pd.cut(white['fixed acidity'], bins=fixed_acidity_bins2, labels=fixed_acidity_bins2[:-1]) 
fixed_acidity_series2.name = 'fa_bin'
white_acidity = pd.concat([white, fixed_acidity_series2], axis=1)
white_acidity2 = white_acidity[white_acidity.iloc[:,-1].astype(float) < 12]
white_acidity2.sort_values('fa_bin')

# 5
reds_above_mean = red[red['alcohol'] > red_alc_mean]
pd.pivot_table(reds_above_mean, values='alcohol', index='quality')

whites_above_mean = white[white['alcohol'] > white_alc_mean]
pd.pivot_table(whites_above_mean, values='alcohol', index='quality')
# 6
pd.pivot_table(red_acidity, values='alcohol', index='fa_bin')
pd.pivot_table(white_acidity, values='alcohol', index='fa_bin')
# Out:
#              alcohol
# fa_bin
# 3.800000   11.274123
# 5.533333   10.532651
# 7.266667   10.378804
# 9.000000   10.090000
# 10.733333   9.700000

# %%
reds_above_mean
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36            6.10      0.071
# 11              7.5             0.500         0.36            6.10      0.071
# 16              8.5             0.280         0.56            1.80      0.092
# 31              6.9             0.685         0.00            2.50      0.105
# 36              7.8             0.600         0.14            2.40      0.086
# 39              7.3             0.450         0.36            5.90      0.074
# 40              7.3             0.450         0.36            5.90      0.074
# 42              7.5             0.490         0.20            2.60      0.332
# 45              4.6             0.520         0.15            2.10      0.054
# 64              7.2             0.725         0.05            4.65      0.086
# 65              7.2             0.725         0.05            4.65      0.086
# 67              6.6             0.705         0.07            1.60      0.076
# 68              9.3             0.320         0.57            2.00      0.074
# 69              8.0             0.705         0.05            1.90      0.074
# 75              8.8             0.410         0.64            2.20      0.093
# 76              8.8             0.410         0.64            2.20      0.093
# 77              6.8             0.785         0.00            2.40      0.104
# 94              5.0             1.020         0.04            1.40      0.045
# 95              4.7             0.600         0.17            2.30      0.058
# 96              6.8             0.775         0.00            3.00      0.102
# 115             9.4             0.400         0.31            2.20      0.090
# 118             8.8             0.550         0.04            2.20      0.119
# 121             8.8             0.550         0.04            2.20      0.119
# 126             8.2             1.330         0.00            1.70      0.081
# 127             8.1             1.330         0.00            1.80      0.082
# 128             8.0             0.590         0.16            1.80      0.065
# 131             5.6             0.500         0.09            2.30      0.049
# 132             5.6             0.500         0.09            2.30      0.049
# 142             5.2             0.340         0.00            1.80      0.050
# 131                  17.0                  99.0  0.99370  3.63       0.63
# 132                  17.0                  99.0  0.99370  3.63       0.63
# 142                  27.0                  63.0  0.99160  3.68       0.79
# 144                  27.0                  63.0  0.99160  3.68       0.79
# ...                   ...                   ...      ...   ...        ...
# 1554                 15.0                  23.0  0.99627  3.54       0.60
# 1555                 15.0                  24.0  0.99514  3.44       0.68
# 1557                 15.0                  23.0  0.99627  3.54       0.60
# 1565                 26.0                  42.0  0.99489  3.39       0.82
# 1566                 24.0                  52.0  0.99494  3.34       0.71
# 1569                 15.0                  34.0  0.99396  3.48       0.57
# 1570                 19.0                  35.0  0.99340  3.37       0.93
# 1571                 15.0                  25.0  0.99514  3.44       0.65
# 1573                 15.0                  50.0  0.99467  3.58       0.67
# 1574                 23.0                  92.0  0.99677  3.39       0.48
# 1575                 12.0                  20.0  0.99474  3.26       0.64
# 1576                 16.0                  29.0  0.99588  3.30       0.78
# 1577                 13.0                  27.0  0.99622  3.54       0.60
# 1578                 13.0                  20.0  0.99540  3.42       0.67
# 1579                 24.0                  32.0  0.99402  3.54       0.60
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 1581                 24.0                  32.0  0.99402  3.54       0.60
# 1582                 13.0                  27.0  0.99362  3.57       0.50
# 1584                 24.0                  34.0  0.99484  3.29       0.80
# 1585                 22.0                  48.0  0.99494  3.30       0.84
# 1586                 34.0                  60.0  0.99492  3.34       0.85
# 1587                 18.0                  28.0  0.99483  3.55       0.66
# 1588                 34.0                 102.0  0.99414  3.27       0.78
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 9       10.50        5
# 11      10.50        5
# 16      10.50        7
# 31      10.60        6
# 36      10.80        6
# 39      10.50        5
# 40      10.50        5
# 42      10.50        6
# 45      13.10        4
# 64      10.90        5
# 65      10.90        5
# 67      10.70        5
# 68      10.70        5
# 69      10.50        6
# 75      10.50        5
# 76      10.50        5
# 77      10.70        6
# 94      10.50        4
# 95      12.90        6
# 96      10.70        5
# 115     10.50        6
# 118     10.90        6
# 121     10.90        6
# 126     10.90        5
# 127     10.90        5
# 128     10.50        7
# 131     13.00        5
# 132     13.00        5
# 142     14.00        6
# 144     14.00        6
# ...       ...      ...
# 1554    11.00        6
# 1555    10.55        7
# 1557    11.00        6
# 1565    10.90        6
# 1566    11.20        6
# 1569    11.50        6
# 1570    12.40        6
# 1571    11.10        6
# 1573    12.50        6
# 1574    10.50        6
# 1575    11.80        6
# 1576    10.80        6
# 1577    11.90        6
# 1578    11.30        6
# 1579    11.30        5
# 1580    11.90        6
# 1581    11.30        5
# 1582    11.90        5
# 1584    11.60        7
# 1585    11.50        6
# 1586    11.40        6
# 1587    10.90        6
# 1588    12.80        6
# 1590    11.60        6
# 1591    11.60        6
# 1592    11.00        6
# 1594    10.50        5
# 1595    11.20        6
# 1596    11.00        6
# 1598    11.00        6
#
# [683 rows x 12 columns]

# %%
red['fixed acidity'].max()
# Out:
# 15.9
